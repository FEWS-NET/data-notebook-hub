# %%
import pandas as pd 
import os
import requests
import csv

# %%
# API URL
api_url = "https://fdw.fews.net/api/classifiedproduct/"

# Make a GET request to the API
response = requests.get(api_url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON data from the response
    data = response.json()

    # Specify the folder path
    folder_path = "data"
    # Create the "data" folder if it doesn't exist
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    # Specify the CSV file path inside the "data" folder
    csv_file_path = os.path.join(folder_path, "api_data.csv")

    # Open the CSV file in write mode
    with open(csv_file_path, 'w', newline='') as csvfile:
        # Create a CSV writer object
        csv_writer = csv.writer(csvfile)

        # Write the header row based on the keys of the first item in the data
        csv_writer.writerow(data[0].keys())

        # Write each row of data to the CSV file
        for row in data:
            csv_writer.writerow(row.values())

    print(f"Data has been successfully saved to {csv_file_path}")
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
# Data has been successfully saved to data/api_data.csv

# %%
df = pd.read_csv('./data/api_data.csv')
df.head()
# Out:
#     cpcv2                                        description  \
# 0      R0         Agriculture, forestry and fishery products
# 1     R01  Products of agriculture, horticulture and mark...
# 2    R011                                            Cereals
# 3   R0111                                              Wheat
# 4  R01111                                Wheat planting seed
#
#                                          common_name  \
# 0                                                NaN
# 1  Agriculture products, horticulture, market gar...
# 2                                                NaN
# 3                                                NaN
# 4                                Wheat planting seed
#
#                                         display_name  \
# 0         Agriculture, forestry and fishery products
# 1  Agriculture products, horticulture, market gar...
# 2                                            Cereals
# 3                                              Wheat
# 4                                Wheat planting seed
#
#                              es_name  \
# 0                                NaN
# 1  Productos agrícolas, horticultura
# 2                                NaN
# 3                                NaN
# 4        Semilla de siembra de trigo
#
#                                         fr_name  \
# 0                                           NaN
# 1  Produits agricoles, horticulture, maraîchage
# 2                                           NaN
# 3                                           NaN
# 4                               Semences de blé
#
#                                              pt_name  ar_name  \
# 0                                                NaN      NaN
# 1  Produtos agrícolas, horticultura, horta comercial      NaN
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4                      Semente de plantação de trigo      NaN
#
#                                              aliases                  hs2012  \
# 0                                                 []                     NaN
# 1                                                 []                     NaN
# 2                                                 []                     NaN
# 3                                                 []                     NaN
# 4  ['semillas de trigo', 'semences de ble', 'trit...  ['1001.11', '1001.91']
#
#      scientific_name per_country_aliases
# 0                NaN                  []
# 1                NaN                  []
# 2                NaN                  []
# 3                NaN                  []
# 4  Triticum aestivum                  []

# %%
df[['cpcv2', 'common_name', 'aliases']][0:20]
# Out:
#        cpcv2                                        common_name  \
# 0         R0                                                NaN
# 1        R01  Agriculture products, horticulture, market gar...
# 2       R011                                                NaN
# 3      R0111                                                NaN
# 4     R01111                                Wheat planting seed
# 5   R01111AA                                Wheat planting seed
# 6     R01112                                                NaN
# 7   R01112AA                                        Wheat Grain
# 8   R01112AB               Wheat Grain (No. 2, Soft Red Winter)
# 9   R01112AC                                  Wheat Grain (ASW)
# 10  R01112AD                                 Wheat Grain (CWRS)
# 11  R01112AE                              Wheat grain (Grade 1)
# 12  R01112AF               Wheat grain (No. 2, Hard Red Winter)
# 13  R01112AG                            Wheat Grain (Trigo Pan)
# 14  R01112AH                             Wheat Grain (Food Aid)
# 15  R01112AI                                      Wheat (Durum)
# 16  R01112AJ                                    Wheat (Einkorn)
# 17  R01112AK                                      Wheat (Emmer)
# 18  R01112AL                                             Meslin
# 19  R01112AM                                    Wheat/Spelt mix
#
#                                               aliases
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   ['semillas de trigo', 'semences de ble', 'trit...
# 5                               ['triticum aestivum']
# 6                               ['triticum aestivum']
# 7   ['imported wheat (grains)', 'froment', 'grurë'...
# 8   ['01112b', 'soft red winter wheat', 'wheat (us...
# 9   ['wheat grain (asw)', '01112c', 'triticum aest...
# 10  ['wheat, other, canadian western red spring', ...
# 11  ['wheat grain (grade 1)', 'wheat, grain, grade...
# 12  ['01112f', 'wheat (us no. 2, hard red winter)'...
# 13  ['bread wheat', '01112g', 'wheat, other, trigo...
# 14  ['wheat (food aid)', 'common wheat', 'wheat, o...
# 15  ['blé dur', 'trigo moruno', 'rivet wheat', 'tr...
# 16  ['escaña menor', 'escaña menor silvestre', 'sm...
# 17  ['dinkel wheat', 'awned wheat', 'hulled wheat'...
# 18                        ['maslin', 'wheat-rye mix']
# 19                                                 []

# %%
df.sample(10)
# Out:
#          cpcv2                                        description  \
# 4416  S64117AB       Bus transport cost, Mabvuku to Fourth Street
# 3687      P491  Motor vehicles, trailers and semi-trailers; pa...
# 601   R01510AE                                  Solanum tuberosum
# 4815    S83118                               Head office services
# 179   R01219BD                               Leafy/Stem Vegetable
# 2938    P39364                            Waste and scrap of lead
# 280   R01259AG                                   cube or barbasco
# 1348     P1513  Granite, sandstone and other monumental or bui...
# 1551    P21419                          Other dried fruit, n.e.c.
# 3627    P48232  Drafting tables and machines, and other drawin...
#
#                                         common_name  \
# 4416  Bus transport cost (Mabvuku to Fourth Street)
# 3687                                            NaN
# 601                                Potatoes (Black)
# 4815                                            NaN
# 179                                      Corn salad
# 2938                                            NaN
# 280                                cube or barbasco
# 1348                                            NaN
# 1551                                            NaN
# 3627                                            NaN
#
#                                            display_name es_name fr_name  \
# 4416      Bus transport cost (Mabvuku to Fourth Street)     NaN     NaN
# 3687  Motor vehicles, trailers and semi-trailers; pa...     NaN     NaN
# 601                                    Potatoes (Black)     NaN     NaN
# 4815                               Head office services     NaN     NaN
# 179                                          Corn salad     NaN     NaN
# 2938                            Waste and scrap of lead     NaN     NaN
# 280                                    cube or barbasco     NaN     NaN
# 1348  Granite, sandstone and other monumental or bui...     NaN     NaN
# 1551                          Other dried fruit, n.e.c.     NaN     NaN
# 3627  Drafting tables and machines, and other drawin...     NaN     NaN
#
#      pt_name  ar_name         aliases  \
# 4416     NaN      NaN             NaN
# 3687     NaN      NaN              []
# 601      NaN      NaN  ['papa negra']
# 4815     NaN      NaN              []
# 179      NaN      NaN             NaN
# 2938     NaN      NaN              []
# 280      NaN      NaN             NaN
# 1348     NaN      NaN              []
# 1551     NaN      NaN              []
# 3627     NaN      NaN              []
#
#                                                  hs2012       scientific_name  \
# 4416                                                NaN                   NaN
# 3687                                                NaN                   NaN
# 601                                                 NaN     Solanum tuberosum
# 4815                                                NaN                   NaN
# 179                                                 NaN  Valerianella locusta
# 2938                                        ['7802.00']                   NaN
# 280                                                 NaN    Lonchocarpus urucu
# 1348                                                NaN                   NaN
# 1551  ['0803.10', '0803.90', '0804.10', '0804.20', '...                   NaN
# 3627                             ['9017.10', '9017.20']                   NaN
#
#      per_country_aliases
# 4416                  []
# 3687                  []
# 601                   []
# 4815                  []
# 179                   []
# 2938                  []
# 280                   []
# 1348                  []
# 1551                  []
# 3627                  []

# %%
dfT = df.T
dfT.head()
# Out:
#                                                     0     \
# cpcv2                                                 R0
# description   Agriculture, forestry and fishery products
# common_name                                          NaN
# display_name  Agriculture, forestry and fishery products
# es_name                                              NaN
#
#                                                            1        2     \
# cpcv2                                                       R01     R011
# description   Products of agriculture, horticulture and mark...  Cereals
# common_name   Agriculture products, horticulture, market gar...      NaN
# display_name  Agriculture products, horticulture, market gar...  Cereals
# es_name                       Productos agrícolas, horticultura      NaN
#
#                3                            4                    5     \
# cpcv2         R0111                       R01111             R01111AA
# description   Wheat          Wheat planting seed  Wheat planting seed
# common_name     NaN          Wheat planting seed  Wheat planting seed
# display_name  Wheat          Wheat planting seed  Wheat planting seed
# es_name         NaN  Semilla de siembra de trigo                  NaN
#
#                         6                   7     \
# cpcv2                 R01112            R01112AA
# description      Wheat grain  Wheat grain, other
# common_name              NaN         Wheat Grain
# display_name     Wheat grain         Wheat Grain
# es_name       Grano de trigo                 NaN
#
#                                               8                  9     ...  \
# cpcv2                                     R01112AB           R01112AC  ...
# description                            Wheat grain        Wheat grain  ...
# common_name   Wheat Grain (No. 2, Soft Red Winter)  Wheat Grain (ASW)  ...
# display_name  Wheat Grain (No. 2, Soft Red Winter)  Wheat Grain (ASW)  ...
# es_name                                        NaN                NaN  ...
#
#                                              5676  \
# cpcv2                                       S9799
# description   Other miscellaneous services n.e.c.
# common_name                                   NaN
# display_name  Other miscellaneous services n.e.c.
# es_name                                       NaN
#
#                                              5677               5678  \
# cpcv2                                      S97990                S98
# description   Other miscellaneous services n.e.c.  Domestic services
# common_name                                   NaN                NaN
# display_name  Other miscellaneous services n.e.c.  Domestic services
# es_name                                       NaN                NaN
#
#                            5679               5680               5681  \
# cpcv2                      S980              S9800             S98000
# description   Domestic services  Domestic services  Domestic services
# common_name                 NaN                NaN                NaN
# display_name  Domestic services  Domestic services  Domestic services
# es_name                     NaN                NaN                NaN
#
#                                                            5682  \
# cpcv2                                                       S99
# description   Services provided by extraterritorial organiza...
# common_name                                                 NaN
# display_name  Services provided by extraterritorial organiza...
# es_name                                                     NaN
#
#                                                            5683  \
# cpcv2                                                      S990
# description   Services provided by extraterritorial organiza...
# common_name                                                 NaN
# display_name  Services provided by extraterritorial organiza...
# es_name                                                     NaN
#
#                                                            5684  \
# cpcv2                                                     S9900
# description   Services provided by extraterritorial organiza...
# common_name                                                 NaN
# display_name  Services provided by extraterritorial organiza...
# es_name                                                     NaN
#
#                                                            5685
# cpcv2                                                    S99000
# description   Services provided by extraterritorial organiza...
# common_name                                                 NaN
# display_name  Services provided by extraterritorial organiza...
# es_name                                                     NaN
#
# [5 rows x 5686 columns]

# %%
df = dfT.T
df['description']
# Out:
# 0              Agriculture, forestry and fishery products
# 1       Products of agriculture, horticulture and mark...
# 2                                                 Cereals
# 3                                                   Wheat
# 4                                     Wheat planting seed
#                               ...
# 5681                                    Domestic services
# 5682    Services provided by extraterritorial organiza...
# 5683    Services provided by extraterritorial organiza...
# 5684    Services provided by extraterritorial organiza...
# 5685    Services provided by extraterritorial organiza...
# Name: description, Length: 5686, dtype: object

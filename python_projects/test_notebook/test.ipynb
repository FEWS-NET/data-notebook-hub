# %%
import numpy as np 
import pandas as pd 
import os
import requests
import csv
import matplotlib.pyplot as plt

# %%
# API URL
api_url = "https://fdw.fews.net/api/classifiedproduct/"

# Make a GET request to the API
response = requests.get(api_url)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Parse the JSON data from the response
    data = response.json()

    # Specify the folder path
    folder_path = "data"

    # Create the "data" folder if it doesn't exist
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

    # Specify the CSV file path inside the "data" folder
    csv_file_path = os.path.join(folder_path, "api_data.csv")

    # Open the CSV file in write mode
    with open(csv_file_path, 'w', newline='') as csvfile:
        # Create a CSV writer object
        csv_writer = csv.writer(csvfile)

        # Write the header row based on the keys of the first item in the data
        csv_writer.writerow(data[0].keys())

        # Write each row of data to the CSV file
        for row in data:
            csv_writer.writerow(row.values())

    print(f"Data has been successfully saved to {csv_file_path}")
else:
    print(f"Failed to fetch data. Status code: {response.status_code}")
# Out:
# Data has been successfully saved to data/api_data.csv

# %%
df = pd.read_csv('./data/api_data.csv')
df.head()
# Out:
#     cpcv2                                        description  \
# 0      R0         Agriculture, forestry and fishery products
# 1     R01  Products of agriculture, horticulture and mark...
# 2    R011                                            Cereals
# 3   R0111                                              Wheat
# 4  R01111                                Wheat planting seed
#
#                                          common_name  \
# 0                                                NaN
# 1  Agriculture products, horticulture, market gar...
# 2                                                NaN
# 3                                                NaN
# 4                                Wheat planting seed
#
#                                         display_name  \
# 0         Agriculture, forestry and fishery products
# 1  Agriculture products, horticulture, market gar...
# 2                                            Cereals
# 3                                              Wheat
# 4                                Wheat planting seed
#
#                              es_name  \
# 0                                NaN
# 1  Productos agrícolas, horticultura
# 2                                NaN
# 3                                NaN
# 4        Semilla de siembra de trigo
#
#                                         fr_name  \
# 0                                           NaN
# 1  Produits agricoles, horticulture, maraîchage
# 2                                           NaN
# 3                                           NaN
# 4                               Semences de blé
#
#                                              pt_name  ar_name  \
# 0                                                NaN      NaN
# 1  Produtos agrícolas, horticultura, horta comercial      NaN
# 2                                                NaN      NaN
# 3                                                NaN      NaN
# 4                      Semente de plantação de trigo      NaN
#
#                                              aliases                  hs2012  \
# 0                                                 []                     NaN
# 1                                                 []                     NaN
# 2                                                 []                     NaN
# 3                                                 []                     NaN
# 4  ['semillas de trigo', 'semences de ble', 'trit...  ['1001.11', '1001.91']
#
#      scientific_name per_country_aliases
# 0                NaN                  []
# 1                NaN                  []
# 2                NaN                  []
# 3                NaN                  []
# 4  Triticum aestivum                  []

# %%
df[['cpcv2', 'common_name', 'aliases']][0:20]
# Out:
#        cpcv2                                        common_name  \
# 0         R0                                                NaN
# 1        R01  Agriculture products, horticulture, market gar...
# 2       R011                                                NaN
# 3      R0111                                                NaN
# 4     R01111                                Wheat planting seed
# 5   R01111AA                                Wheat planting seed
# 6     R01112                                                NaN
# 7   R01112AA                                        Wheat Grain
# 8   R01112AB               Wheat Grain (No. 2, Soft Red Winter)
# 9   R01112AC                                  Wheat Grain (ASW)
# 10  R01112AD                                 Wheat Grain (CWRS)
# 11  R01112AE                              Wheat grain (Grade 1)
# 12  R01112AF               Wheat grain (No. 2, Hard Red Winter)
# 13  R01112AG                            Wheat Grain (Trigo Pan)
# 14  R01112AH                             Wheat Grain (Food Aid)
# 15  R01112AI                                      Wheat (Durum)
# 16  R01112AJ                                    Wheat (Einkorn)
# 17  R01112AK                                      Wheat (Emmer)
# 18  R01112AL                                             Meslin
# 19  R01112AM                                    Wheat/Spelt mix
#
#                                               aliases
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4   ['semillas de trigo', 'semences de ble', 'trit...
# 5                               ['triticum aestivum']
# 6                               ['triticum aestivum']
# 7   ['imported wheat (grains)', 'froment', 'grurë'...
# 8   ['01112b', 'soft red winter wheat', 'wheat (us...
# 9   ['wheat grain (asw)', '01112c', 'triticum aest...
# 10  ['wheat, other, canadian western red spring', ...
# 11  ['wheat grain (grade 1)', 'wheat, grain, grade...
# 12  ['01112f', 'wheat (us no. 2, hard red winter)'...
# 13  ['bread wheat', '01112g', 'wheat, other, trigo...
# 14  ['wheat (food aid)', 'common wheat', 'wheat, o...
# 15  ['blé dur', 'trigo moruno', 'rivet wheat', 'tr...
# 16  ['escaña menor', 'escaña menor silvestre', 'sm...
# 17  ['dinkel wheat', 'awned wheat', 'hulled wheat'...
# 18                        ['maslin', 'wheat-rye mix']
# 19                                                 []

# %%
df.sample(10)
# Out:
#          cpcv2                                        description  \
# 4411    S64115                                      Taxi services
# 4348    S62565  Retail trade services on a fee or contract bas...
# 2583     P3544  Modelling pastes; "dental wax" or "dental impr...
# 5387     S9119    Other administrative services of the government
# 3669    P48342  Chemical preparations for photographic uses, e...
# 5620    S96412  Preservation services of historical sites and ...
# 2228     P3191                             Other products of wood
# 4135    S62233  Specialized store retail trade services, of ar...
# 313   R01313AE                                     Cooking banana
# 2973    P41121  Non-alloy steel in ingots or other primary for...
#
#             common_name                                       display_name  \
# 4411                NaN                                      Taxi services
# 4348                NaN  Retail trade services on a fee or contract bas...
# 2583                NaN  Modelling pastes; "dental wax" or "dental impr...
# 5387                NaN    Other administrative services of the government
# 3669                NaN  Chemical preparations for photographic uses, e...
# 5620                NaN  Preservation services of historical sites and ...
# 2228                NaN                             Other products of wood
# 4135                NaN  Specialized store retail trade services, of ar...
# 313   AAB-type plantain                                  AAB-type plantain
# 2973                NaN  Non-alloy steel in ingots or other primary for...
#
#      es_name fr_name pt_name  ar_name aliases  \
# 4411     NaN     NaN     NaN      NaN      []
# 4348     NaN     NaN     NaN      NaN      []
# 2583     NaN     NaN     NaN      NaN      []
# 5387     NaN     NaN     NaN      NaN      []
# 3669     NaN     NaN     NaN      NaN      []
# 5620     NaN     NaN     NaN      NaN      []
# 2228     NaN     NaN     NaN      NaN      []
# 4135     NaN     NaN     NaN      NaN      []
# 313      NaN     NaN     NaN      NaN     NaN
# 2973     NaN     NaN     NaN      NaN      []
#
#                                                  hs2012  scientific_name  \
# 4411                                                NaN              NaN
# 4348                                                NaN              NaN
# 2583                                                NaN              NaN
# 5387                                                NaN              NaN
# 3669                             ['3707.10', '3707.90']              NaN
# 5620                                                NaN              NaN
# 2228                                                NaN              NaN
# 4135                                                NaN              NaN
# 313                                                 NaN  Musa balbisiana
# 2973  ['7206.10', '7206.90', '7207.11', '7207.12', '...              NaN
#
#      per_country_aliases
# 4411                  []
# 4348                  []
# 2583                  []
# 5387                  []
# 3669                  []
# 5620                  []
# 2228                  []
# 4135                  []
# 313                   []
# 2973                  []
